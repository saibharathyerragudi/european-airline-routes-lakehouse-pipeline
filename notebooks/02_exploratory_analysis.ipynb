# %% [markdown]
# # Notebook Analysis
# ## loading the cleaned data

# %%
clean_df = spark.table("databricks_course_s.eu_air_routes.eu_air_routes_clean")

# %% [markdown]
# ## Basic Schema Overview

# %%
clean_df.printSchema()
# Out:
# root
#  |-- id: double (nullable = true)
#  |-- iata_from: string (nullable = true)
#  |-- iata_to: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- day1: string (nullable = true)
#  |-- day2: string (nullable = true)
#  |-- day3: string (nullable = true)
#  |-- day4: string (nullable = true)
#  |-- day5: string (nullable = true)
#  |-- day6: string (nullable = true)
#  |-- day7: string (nullable = true)
#  |-- flights_per_day: string (nullable = true)
#  |-- common_duration: double (nullable = true)
#  |-- flights_per_week: double (nullable = true)
#  |-- first_flight: string (nullable = true)
#  |-- last_flight: date (nullable = true)
#  |-- airlineroutes: string (nullable = true)
#  |-- arrival_airport_country_code: string (nullable = true)
#  |-- arrival_airport_name: string (nullable = true)
#  |-- arrival_airport_city_name: string (nullable = true)
#  |-- arrival_airport_city_name_en: string (nullable = true)
# ...

# %% [markdown]
# ## row count

# %%
clean_df.count()
# Out:
# 18111

# %% [markdown]
# ## Preview the Data

# %%
display(clean_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## statisticts for numeric columns

# %%
numeric_cols = [
    "price", "common_duration", "flights_per_week",
    "arrival_airport_no_routes",
    "departure_latitude", "departure_longitude",
    "arrival_latitude", "arrival_longitude",
    "distance_km", "price_per_km", "days_operated"
]

clean_df.select(numeric_cols).describe().show()
# Out:
# +-------+------------------+------------------+------------------+-------------------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+
# |summary|             price|   common_duration|  flights_per_week|arrival_airport_no_routes|departure_latitude|departure_longitude|  arrival_latitude| arrival_longitude|       distance_km|      price_per_km|     days_operated|
# +-------+------------------+------------------+------------------+-------------------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+
# |  count|             18111|             18111|             18111|                    18111|             18111|              18111|             18017|             18017|             18017|             18017|             18111|
# ...

# %% [markdown]
# ## Count null values per column

# %%
from pyspark.sql import functions as F

null_counts = clean_df.select([
    F.sum(F.col(c).isNull().cast("int")).alias(c + "_nulls") 
    for c in clean_df.columns
])

display(null_counts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Top 10 Busiest Departure Airports

# %%
(
    clean_df.groupBy("iata_from")
    .agg(F.sum("flights_per_week").alias("total_flights"))
    .orderBy(F.col("total_flights").desc())
    .limit(10)
).show()
# Out:
# +---------+-------------+
# |iata_from|total_flights|
# +---------+-------------+
# |      IST|       7748.0|
# |      AMS|       4747.0|
# |      LHR|       4721.0|
# |      FRA|       4585.0|
# |      CDG|       4091.0|
# |      MAD|       3797.0|
# |      BCN|       3541.0|
# |      MUC|       2998.0|
# |      FCO|       2833.0|
# |      ATH|       2683.0|
# +---------+-------------+

# %% [markdown]
# ## distrubution of days operated

# %%
clean_df.groupBy("days_operated").count().orderBy("days_operated").show()
# Out:
# +-------------+-----+
# |days_operated|count|
# +-------------+-----+
# |            0| 4244|
# |            1|  876|
# |            2| 2375|
# |            3| 1619|
# |            4| 1344|
# |            5| 1080|
# |            6|  978|
# |            7| 5595|
# +-------------+-----+

# %% [markdown]
# ## Basic correlation check (price vs distance)

# %%
clean_df.select("price", "distance_km").stat.corr("price", "distance_km")
# Out:
# 0.377139283350175

# %% [markdown]
# # Departure vs Arrival Cooridinates

# %%
import matplotlib.pyplot as plt

geo_pdf = clean_df.select(
    "departure_latitude", "departure_longitude",
    "arrival_latitude", "arrival_longitude"
).dropna().limit(8000).toPandas()

plt.figure(figsize=(10, 10))

plt.scatter(
    geo_pdf["departure_longitude"],
    geo_pdf["departure_latitude"],
    alpha=0.35,
    label="Departure Points"
)

plt.scatter(
    geo_pdf["arrival_longitude"],
    geo_pdf["arrival_latitude"],
    alpha=0.35,
    label="Arrival Points"
)

plt.title("European Air Routes – Geographic Scatter of Departure vs Arrival Airports")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend()
plt.show()

# %% [markdown]
# #Distribution of Route Distances

# %%
dist_pdf = clean_df.select("distance_km").dropna().toPandas()

plt.figure(figsize=(10, 5))
plt.hist(dist_pdf["distance_km"], bins=40, edgecolor="black")
plt.title("Distribution of Route Distances (km)")
plt.xlabel("Distance (km)")
plt.ylabel("Number of Routes")
plt.show()

# %% [markdown]
# # price vs distance relationship

# %%
price_pdf = clean_df.select("distance_km", "price").dropna().toPandas()

plt.figure(figsize=(10, 6))
plt.scatter(price_pdf["distance_km"], price_pdf["price"], alpha=0.4)
plt.title("Relationship Between Flight Distance and Ticket Price")
plt.xlabel("Distance (km)")
plt.ylabel("Price (€)")
plt.show()

# %% [markdown]
# #Weekly Flight Volume by Departure Country

# %%
country_df = (
    clean_df.groupBy("departure_country")
    .agg(F.sum("flights_per_week").alias("total_flights"))
    .orderBy(F.col("total_flights").desc())
).toPandas()

plt.figure(figsize=(14, 6))
plt.bar(country_df["departure_country"], country_df["total_flights"])
plt.xticks(rotation=45, ha="right")
plt.xlabel("Departure Country")
plt.ylabel("Total Weekly Flights")
plt.title("Total Weekly Flights by Departure Country")
plt.show()
